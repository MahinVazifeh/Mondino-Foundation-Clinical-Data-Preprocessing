# %%
import numpy as np
import pandas as pd
import math

# %%
def calculate_age_at_visit(row):
    date_of_birth = row['Date of birth']
    date_of_visit = row['Date_of_visit']
    age = date_of_visit.year - date_of_birth.year - ((date_of_visit.month, date_of_visit.day) < (date_of_birth.month, date_of_birth.day))
    return age

# %%
Age = pd.read_csv("C:/Users/Mahin Vazifehdan/Desktop/Datasets/BrainTeaser/Other data/Patient_CAP.csv")
incomplete_FS_Score = pd.read_csv("Updated_MS_with_relapse.csv")
incomplete_FS_Score.head()

# %%
incomplete_FS_Score.drop_duplicates(subset=["Patient_ID", "Date_of_visit"],
                          keep = "first",
                          inplace=True, 
                          ignore_index=True)

incomplete_FS_Score['Date_of_visit'] = pd.to_datetime(incomplete_FS_Score['Date_of_visit'], format ='%d/%m/%Y')
incomplete_FS_Score['Patient_ID']=incomplete_FS_Score['Patient_ID'].astype(object)
Age['Data di nascita'] = pd.to_datetime(Age['Data di nascita'])

incomplete_FS_Score.dropna(inplace=True)

final_data = incomplete_FS_Score.merge(Age, left_on='Patient_ID', right_on = "Paziente ID", how='left')
final_data['Age'] = final_data.apply(calculate_age_at_visit, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22300\124102977.py in <module>
#       4                           ignore_index=True)
#       5
# ----> 6 incomplete_FS_Score['Date_of_visit'] = pd.to_datetime(incomplete_FS_Score['Date_of_visit'], format ='%d/%m/%Y')
#       7 incomplete_FS_Score['Patient_ID']=incomplete_FS_Score['Patient_ID'].astype(object)
#       8 Age['Data di nascita'] = pd.to_datetime(Age['Data di nascita'])
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     392     if format is not None:
#     393         res = _to_datetime_with_format(
# --> 394             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     395         )
#     396         if res is not None:
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     511             return DatetimeIndex._simple_new(dta, name=name)
#     512         except (ValueError, TypeError):
# --> 513             raise err
#     514
#     515
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     499         # fallback
#     500         res = _array_strptime_with_fallback(
# --> 501             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     502         )
#     503         return res
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434
#     435     try:
# --> 436         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     437         if "%Z" in fmt or "%z" in fmt:
#     438             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# c:\users\mahin vazifehdan\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2013-05-07' does not match format '%d/%m/%Y' (match)

# %%
final_data.to_csv("Complete_Clinical_Data_12000.csv", index = False)
